# %%
import os
import numpy as np
import pydicom
import tensorflow as tf
from skimage.transform import resize
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras import layers, optimizers, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import AUC
from tensorflow.keras.optimizers.schedules import CosineDecay
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
#from keras.src import layers
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.optimizers.schedules import CosineDecay

from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc, confusion_matrix
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img

# %%
# Paths
image_path_base = r'C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\png'
text_path_base = r'C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\myver_cleanCropCMMD.csv'

def get_image_paths_and_labels():
    image_paths = []
    labels = []
    b_count = 0
    m_count = 0

    with open(text_path_base) as f:
        f.readline()

        for line in f:
            splitLine = line.split(",")

            imagePath = splitLine[2].replace("\n", "").replace('"',"") 
            image_paths.append(imagePath)

            classification = splitLine[1].replace('"', '') 
            if classification == "0":
              labels.append(np.array([0]))
              b_count += 1
            if classification == "1":
              labels.append(np.array([1]))
              m_count += 1

    print(f"Benign count: {b_count}")
    print(f"Malignant count: {m_count}")
    return np.array(image_paths), np.array(labels)

image_paths, labels = get_image_paths_and_labels()

# separate benign and malignant paths
benign_paths = image_paths[labels.flatten() == 0]
malignant_paths = image_paths[labels.flatten() == 1]

# Balance the dataset
num_to_augment = len(malignant_paths) - len(benign_paths)
print(f"\nNeed to augment {num_to_augment} benign images.")



# paths_train, paths_test, y_train, y_test = train_test_split(
#     image_paths, labels, test_size=0.2, random_state=1
# )
# Out:
# Benign count: 1416
# Malignant count: 4174
#
# Need to augment 2758 benign images.

# %%
augmented_dir = os.path.join(image_path_base, "augmented_benign")
os.makedirs(augmented_dir, exist_ok=True)

augmenter = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.1,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# Generate augmented benign images
augmented_paths = []
count = 0
i = 0

while count < num_to_augment:
    img_path = benign_paths[i % len(benign_paths)]
    try:
        img = load_img(img_path)
    except Exception as e:
        print(f"Skipping {img_path} due to error: {e}")
        i += 1
        continue

    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    for batch in augmenter.flow(x, batch_size=1):
        new_filename = f"benign_aug_{count}.png"
        new_path = os.path.join(augmented_dir, new_filename)

        array_to_img(batch[0]).save(new_path)
        augmented_paths.append(new_path)
        count += 1
        print(f"count: {count}")
        break  # Save 1 per image

    i += 1

print(f"\nSaved {len(augmented_paths)} augmented benign images.")

# Combine original + augmented data
augmented_labels = np.zeros((len(augmented_paths), 1))

image_paths_balanced = np.concatenate([image_paths, np.array(augmented_paths)])
labels_balanced = np.concatenate([labels, augmented_labels])

# Shuffle
indices = np.arange(len(image_paths_balanced))
np.random.shuffle(indices)

image_paths_balanced = image_paths_balanced[indices]
labels_balanced = labels_balanced[indices]

print(f"\nFinal training set: {len(image_paths_balanced)} images (Benign: {np.sum(labels_balanced == 0)}, Malignant: {np.sum(labels_balanced == 1)})")
# Out:
# count: 1
# count: 2
# count: 3
# count: 4
# count: 5
# count: 6
# count: 7
# count: 8
# count: 9
# count: 10
# count: 11
# count: 12
# count: 13
# count: 14
# count: 15
# count: 16
# count: 17
# count: 18
# count: 19
# count: 20
# count: 21
# count: 22
# count: 23
# count: 24
# count: 25
# count: 26
# count: 27
# count: 28
# count: 29
# count: 30
# count: 31
# count: 2746
# count: 2747
# count: 2748
# count: 2749
# count: 2750
# count: 2751
# count: 2752
# count: 2753
# count: 2754
# count: 2755
# count: 2756
# count: 2757
# count: 2758
#
# Saved 2758 augmented benign images.
#
# Final training set: 8348 images (Benign: 4174, Malignant: 4174)

# %%
# Split into training and testing sets (80/20 split)
paths_train, paths_test, y_train, y_test = train_test_split(
    image_paths_balanced,
    labels_balanced,
    test_size=0.2,
    random_state=42,
    stratify=labels_balanced  # ensures same class distribution
)

print(f"Training set: {len(paths_train)} images")
print(f"Test set: {len(paths_test)} images")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Split into training and testing sets (80/20 split)
#       2 paths_train, paths_test, y_train, y_test = train_test_split(
# ----> 3     image_paths_balanced,
#       4     labels_balanced,
#       5     test_size=0.2,
#       6     random_state=42,
#       7     stratify=labels_balanced  # ensures same class distribution
#       8 )
#      10 print(f"Training set: {len(paths_train)} images")
#      11 print(f"Test set: {len(paths_test)} images")
#
# NameError: name 'image_paths_balanced' is not defined

# %%
class DataGenerator:
    def __init__(self, image_paths, labels, batch_size=32, augment=False):
        self.image_paths = image_paths
        self.labels = labels
        self.batch_size = batch_size
        self.augment = augment
        self.datagen = ImageDataGenerator(
            rotation_range=20,
            zoom_range=0.1,
            horizontal_flip=True
        ) if augment else None

    def __len__(self):
        return int(np.ceil(len(self.image_paths) / self.batch_size))

    def __getitem__(self, idx):
        batch_paths = self.image_paths[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_labels = self.labels[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_images = []
        for path in batch_paths:

            img = load_img(path, color_mode='rgb')
            img_array = img_to_array(img)
            img_tensor = tf.convert_to_tensor(img_array)
            img = tf.image.resize_with_pad(img_tensor, 600, 600)
            batch_images.append(img)

        X = np.array(batch_images)
        y = np.array(batch_labels).reshape(-1, 1)

        if self.augment:
            for i in range(len(X)):
                if np.random.random() > 0.5: 
                    X[i] = self.datagen.random_transform(X[i])

        return X, y

    def generate(self):
        while True:
            indices = np.random.permutation(len(self.image_paths))
            self.image_paths = self.image_paths[indices]
            self.labels = self.labels[indices]

            for i in range(len(self)):
                yield self.__getitem__(i)

train_gen = DataGenerator(paths_train, y_train, batch_size=32, augment=True)
test_gen = DataGenerator(paths_test, y_test, batch_size=32, augment=False)

# %%
# Load pretrained ResNet50
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(600, 600, 3))
base_model.trainable = False

x = layers.GlobalAveragePooling2D()(base_model.output)
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
x = layers.Dropout(0.5)(x)
output = layers.Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=optimizers.Adam(learning_rate=1e-4),
              loss="binary_crossentropy",
              metrics=["accuracy", tf.keras.metrics.AUC(name='auc')])

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6
)

checkpoint_best = ModelCheckpoint(
    filepath=r'C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

checkpoint_all = ModelCheckpoint(
    filepath=r'C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_{epoch:02d}_valacc_{val_accuracy:.2f}.weights.h5',
    save_weights_only=True,
    monitor='val_accuracy',  # Or any metric
    mode='max',
    save_best_only=False,
    verbose=1
)

# %%
history = model.fit(
    train_gen.generate(),
    steps_per_epoch=len(train_gen),
    validation_data=test_gen.generate(),
    validation_steps=len(test_gen),
    epochs=100,
    callbacks=[early_stop, reduce_lr, checkpoint_best, checkpoint_all]
)
# Out:
# Epoch 1/100
# 209/209 [==============================] - ETA: 0s - loss: 0.8700 - accuracy: 0.7326 - auc: 0.8027
# Epoch 1: val_loss improved from inf to 0.78502, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 1: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_01_valacc_0.76.weights.h5
# 209/209 [==============================] - 1324s 6s/step - loss: 0.8700 - accuracy: 0.7326 - auc: 0.8027 - val_loss: 0.7850 - val_accuracy: 0.7605 - val_auc: 0.8388 - lr: 1.0000e-04
# Epoch 2/100
# 209/209 [==============================] - ETA: 0s - loss: 0.7654 - accuracy: 0.7528 - auc: 0.8262
# Epoch 2: val_loss improved from 0.78502 to 0.71659, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 2: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_02_valacc_0.76.weights.h5
# 209/209 [==============================] - 1268s 6s/step - loss: 0.7654 - accuracy: 0.7528 - auc: 0.8262 - val_loss: 0.7166 - val_accuracy: 0.7641 - val_auc: 0.8465 - lr: 1.0000e-04
# Epoch 3/100
# 209/209 [==============================] - ETA: 0s - loss: 0.7173 - accuracy: 0.7609 - auc: 0.8318
# Epoch 3: val_loss improved from 0.71659 to 0.69056, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 3: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_03_valacc_0.76.weights.h5
# 209/209 [==============================] - 1266s 6s/step - loss: 0.7173 - accuracy: 0.7609 - auc: 0.8318 - val_loss: 0.6906 - val_accuracy: 0.7593 - val_auc: 0.8424 - lr: 1.0000e-04
# Epoch 4/100
# 209/209 [==============================] - ETA: 0s - loss: 0.6804 - accuracy: 0.7664 - auc: 0.8372
# Epoch 4: val_loss improved from 0.69056 to 0.65483, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 4: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_04_valacc_0.77.weights.h5
# 209/209 [==============================] - 1266s 6s/step - loss: 0.6804 - accuracy: 0.7664 - auc: 0.8372 - val_loss: 0.6548 - val_accuracy: 0.7701 - val_auc: 0.8571 - lr: 1.0000e-04
# Epoch 5/100
# 209/209 [==============================] - ETA: 0s - loss: 0.6515 - accuracy: 0.7749 - auc: 0.8456
# Epoch 5: val_loss improved from 0.65483 to 0.64085, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 5: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_05_valacc_0.77.weights.h5
# 209/209 [==============================] - 1245s 6s/step - loss: 0.6515 - accuracy: 0.7749 - auc: 0.8456 - val_loss: 0.6409 - val_accuracy: 0.7713 - val_auc: 0.8484 - lr: 1.0000e-04
# Epoch 6/100
# 209/209 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.7806 - auc: 0.8504
# Epoch 6: val_loss improved from 0.64085 to 0.61466, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 6: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_06_valacc_0.78.weights.h5
# 209/209 [==============================] - 1248s 6s/step - loss: 0.6291 - accuracy: 0.7806 - auc: 0.8504 - val_loss: 0.6147 - val_accuracy: 0.7802 - val_auc: 0.8568 - lr: 1.0000e-04
# Epoch 7/100
# 209/209 [==============================] - ETA: 0s - loss: 0.6151 - accuracy: 0.7784 - auc: 0.8510
# Epoch 7: val_loss did not improve from 0.61466
#
# Epoch 7: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_07_valacc_0.77.weights.h5
# 209/209 [==============================] - 1241s 6s/step - loss: 0.6151 - accuracy: 0.7784 - auc: 0.8510 - val_loss: 0.6252 - val_accuracy: 0.7749 - val_auc: 0.8572 - lr: 1.0000e-04
# Epoch 8/100
# 209/209 [==============================] - ETA: 0s - loss: 0.6032 - accuracy: 0.7845 - auc: 0.8493
# Epoch 8: val_loss improved from 0.61466 to 0.58427, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 8: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_08_valacc_0.79.weights.h5
# 209/209 [==============================] - 1242s 6s/step - loss: 0.6032 - accuracy: 0.7845 - auc: 0.8493 - val_loss: 0.5843 - val_accuracy: 0.7850 - val_auc: 0.8655 - lr: 1.0000e-04
# Epoch 9/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5886 - accuracy: 0.7874 - auc: 0.8543
# Epoch 9: val_loss improved from 0.58427 to 0.57402, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 9: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_09_valacc_0.78.weights.h5
# 209/209 [==============================] - 1241s 6s/step - loss: 0.5886 - accuracy: 0.7874 - auc: 0.8543 - val_loss: 0.5740 - val_accuracy: 0.7826 - val_auc: 0.8683 - lr: 1.0000e-04
# Epoch 10/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5828 - accuracy: 0.7830 - auc: 0.8532
# Epoch 10: val_loss improved from 0.57402 to 0.57168, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 10: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_10_valacc_0.77.weights.h5
# 209/209 [==============================] - 1239s 6s/step - loss: 0.5828 - accuracy: 0.7830 - auc: 0.8532 - val_loss: 0.5717 - val_accuracy: 0.7743 - val_auc: 0.8600 - lr: 1.0000e-04
# Epoch 11/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5671 - accuracy: 0.7928 - auc: 0.8587
# Epoch 11: val_loss improved from 0.57168 to 0.56809, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 11: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_11_valacc_0.78.weights.h5
# 209/209 [==============================] - 1246s 6s/step - loss: 0.5671 - accuracy: 0.7928 - auc: 0.8587 - val_loss: 0.5681 - val_accuracy: 0.7802 - val_auc: 0.8564 - lr: 1.0000e-04
# Epoch 12/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5615 - accuracy: 0.7868 - auc: 0.8570
# Epoch 12: val_loss improved from 0.56809 to 0.56038, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 12: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_12_valacc_0.79.weights.h5
# 209/209 [==============================] - 1242s 6s/step - loss: 0.5615 - accuracy: 0.7868 - auc: 0.8570 - val_loss: 0.5604 - val_accuracy: 0.7880 - val_auc: 0.8755 - lr: 1.0000e-04
# Epoch 13/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5560 - accuracy: 0.7917 - auc: 0.8561
# Epoch 13: val_loss improved from 0.56038 to 0.54551, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 13: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_13_valacc_0.78.weights.h5
# 209/209 [==============================] - 1242s 6s/step - loss: 0.5560 - accuracy: 0.7917 - auc: 0.8561 - val_loss: 0.5455 - val_accuracy: 0.7808 - val_auc: 0.8621 - lr: 1.0000e-04
# Epoch 14/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5468 - accuracy: 0.7926 - auc: 0.8590
# Epoch 14: val_loss did not improve from 0.54551
#
# Epoch 14: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_14_valacc_0.78.weights.h5
# 209/209 [==============================] - 1245s 6s/step - loss: 0.5468 - accuracy: 0.7926 - auc: 0.8590 - val_loss: 0.5468 - val_accuracy: 0.7760 - val_auc: 0.8607 - lr: 1.0000e-04
# Epoch 15/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5371 - accuracy: 0.7919 - auc: 0.8636
# Epoch 15: val_loss improved from 0.54551 to 0.53778, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 15: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_15_valacc_0.79.weights.h5
# 209/209 [==============================] - 1243s 6s/step - loss: 0.5371 - accuracy: 0.7919 - auc: 0.8636 - val_loss: 0.5378 - val_accuracy: 0.7898 - val_auc: 0.8676 - lr: 1.0000e-04
# Epoch 16/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5334 - accuracy: 0.7957 - auc: 0.8628
# Epoch 16: val_loss did not improve from 0.53778
#
# Epoch 16: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_16_valacc_0.79.weights.h5
# 209/209 [==============================] - 1251s 6s/step - loss: 0.5334 - accuracy: 0.7957 - auc: 0.8628 - val_loss: 0.5419 - val_accuracy: 0.7868 - val_auc: 0.8587 - lr: 1.0000e-04
# Epoch 17/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5286 - accuracy: 0.7969 - auc: 0.8632
# Epoch 17: val_loss improved from 0.53778 to 0.52683, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 17: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_17_valacc_0.78.weights.h5
# 209/209 [==============================] - 1246s 6s/step - loss: 0.5286 - accuracy: 0.7969 - auc: 0.8632 - val_loss: 0.5268 - val_accuracy: 0.7814 - val_auc: 0.8670 - lr: 1.0000e-04
# Epoch 18/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5207 - accuracy: 0.7959 - auc: 0.8658
# Epoch 18: val_loss improved from 0.52683 to 0.52359, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 18: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_18_valacc_0.79.weights.h5
# 209/209 [==============================] - 1249s 6s/step - loss: 0.5207 - accuracy: 0.7959 - auc: 0.8658 - val_loss: 0.5236 - val_accuracy: 0.7856 - val_auc: 0.8696 - lr: 1.0000e-04
# Epoch 19/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5163 - accuracy: 0.7969 - auc: 0.8677
# Epoch 19: val_loss improved from 0.52359 to 0.52000, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 19: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_19_valacc_0.79.weights.h5
# 209/209 [==============================] - 1215s 6s/step - loss: 0.5163 - accuracy: 0.7969 - auc: 0.8677 - val_loss: 0.5200 - val_accuracy: 0.7886 - val_auc: 0.8664 - lr: 1.0000e-04
# Epoch 20/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5120 - accuracy: 0.7948 - auc: 0.8666
# Epoch 20: val_loss improved from 0.52000 to 0.49894, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 20: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_20_valacc_0.80.weights.h5
# 209/209 [==============================] - 1213s 6s/step - loss: 0.5120 - accuracy: 0.7948 - auc: 0.8666 - val_loss: 0.4989 - val_accuracy: 0.7976 - val_auc: 0.8784 - lr: 1.0000e-04
# Epoch 21/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5070 - accuracy: 0.7993 - auc: 0.8702
# Epoch 21: val_loss did not improve from 0.49894
#
# Epoch 21: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_21_valacc_0.79.weights.h5
# 209/209 [==============================] - 1208s 6s/step - loss: 0.5070 - accuracy: 0.7993 - auc: 0.8702 - val_loss: 0.5190 - val_accuracy: 0.7892 - val_auc: 0.8646 - lr: 1.0000e-04
# Epoch 22/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5012 - accuracy: 0.8031 - auc: 0.8707
# Epoch 22: val_loss did not improve from 0.49894
#
# Epoch 22: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_22_valacc_0.79.weights.h5
# 209/209 [==============================] - 1214s 6s/step - loss: 0.5012 - accuracy: 0.8031 - auc: 0.8707 - val_loss: 0.5149 - val_accuracy: 0.7862 - val_auc: 0.8690 - lr: 1.0000e-04
# Epoch 23/100
# 209/209 [==============================] - ETA: 0s - loss: 0.5002 - accuracy: 0.7984 - auc: 0.8712
# Epoch 23: val_loss did not improve from 0.49894
#
# Epoch 23: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_23_valacc_0.78.weights.h5
# 209/209 [==============================] - 1210s 6s/step - loss: 0.5002 - accuracy: 0.7984 - auc: 0.8712 - val_loss: 0.5158 - val_accuracy: 0.7796 - val_auc: 0.8623 - lr: 1.0000e-04
# Epoch 24/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.8100 - auc: 0.8728
# Epoch 24: val_loss improved from 0.49894 to 0.49402, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 24: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_24_valacc_0.80.weights.h5
# 209/209 [==============================] - 1230s 6s/step - loss: 0.4939 - accuracy: 0.8100 - auc: 0.8728 - val_loss: 0.4940 - val_accuracy: 0.7994 - val_auc: 0.8764 - lr: 5.0000e-05
# Epoch 25/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.8032 - auc: 0.8764
# Epoch 25: val_loss did not improve from 0.49402
#
# Epoch 25: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_25_valacc_0.79.weights.h5
# 209/209 [==============================] - 2203s 11s/step - loss: 0.4890 - accuracy: 0.8032 - auc: 0.8764 - val_loss: 0.5046 - val_accuracy: 0.7886 - val_auc: 0.8666 - lr: 5.0000e-05
# Epoch 26/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4889 - accuracy: 0.8065 - auc: 0.8754
# Epoch 26: val_loss improved from 0.49402 to 0.48717, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 26: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_26_valacc_0.80.weights.h5
# 209/209 [==============================] - 1225s 6s/step - loss: 0.4889 - accuracy: 0.8065 - auc: 0.8754 - val_loss: 0.4872 - val_accuracy: 0.7994 - val_auc: 0.8748 - lr: 5.0000e-05
# Epoch 27/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4837 - accuracy: 0.8046 - auc: 0.8765
# Epoch 27: val_loss did not improve from 0.48717
#
# Epoch 27: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_27_valacc_0.79.weights.h5
# 209/209 [==============================] - 1243s 6s/step - loss: 0.4837 - accuracy: 0.8046 - auc: 0.8765 - val_loss: 0.5154 - val_accuracy: 0.7880 - val_auc: 0.8672 - lr: 5.0000e-05
# Epoch 28/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4836 - accuracy: 0.8065 - auc: 0.8767
# Epoch 28: val_loss did not improve from 0.48717
#
# Epoch 28: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_28_valacc_0.80.weights.h5
# 209/209 [==============================] - 4902s 24s/step - loss: 0.4836 - accuracy: 0.8065 - auc: 0.8767 - val_loss: 0.4878 - val_accuracy: 0.8036 - val_auc: 0.8739 - lr: 5.0000e-05
# Epoch 29/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4835 - accuracy: 0.8058 - auc: 0.8753
# Epoch 29: val_loss did not improve from 0.48717
#
# Epoch 29: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_29_valacc_0.80.weights.h5
# 209/209 [==============================] - 1921s 9s/step - loss: 0.4835 - accuracy: 0.8058 - auc: 0.8753 - val_loss: 0.4950 - val_accuracy: 0.7952 - val_auc: 0.8736 - lr: 5.0000e-05
# Epoch 30/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4765 - accuracy: 0.8119 - auc: 0.8794
# Epoch 30: val_loss did not improve from 0.48717
#
# Epoch 30: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_30_valacc_0.78.weights.h5
# 209/209 [==============================] - 2396s 11s/step - loss: 0.4765 - accuracy: 0.8119 - auc: 0.8794 - val_loss: 0.5065 - val_accuracy: 0.7808 - val_auc: 0.8577 - lr: 2.5000e-05
# Epoch 31/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4791 - accuracy: 0.8043 - auc: 0.8790
# Epoch 31: val_loss improved from 0.48717 to 0.48440, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 31: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_31_valacc_0.80.weights.h5
# 209/209 [==============================] - 2009s 10s/step - loss: 0.4791 - accuracy: 0.8043 - auc: 0.8790 - val_loss: 0.4844 - val_accuracy: 0.7952 - val_auc: 0.8812 - lr: 2.5000e-05
# Epoch 32/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4731 - accuracy: 0.8098 - auc: 0.8821
# Epoch 32: val_loss did not improve from 0.48440
#
# Epoch 32: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_32_valacc_0.80.weights.h5
# 209/209 [==============================] - 1782s 9s/step - loss: 0.4731 - accuracy: 0.8098 - auc: 0.8821 - val_loss: 0.4916 - val_accuracy: 0.7958 - val_auc: 0.8721 - lr: 2.5000e-05
# Epoch 33/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4700 - accuracy: 0.8115 - auc: 0.8833
# Epoch 33: val_loss did not improve from 0.48440
#
# Epoch 33: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_33_valacc_0.79.weights.h5
# 209/209 [==============================] - 1668s 8s/step - loss: 0.4700 - accuracy: 0.8115 - auc: 0.8833 - val_loss: 0.4907 - val_accuracy: 0.7886 - val_auc: 0.8684 - lr: 2.5000e-05
# Epoch 34/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4724 - accuracy: 0.8098 - auc: 0.8817
# Epoch 34: val_loss did not improve from 0.48440
#
# Epoch 34: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_34_valacc_0.80.weights.h5
# 209/209 [==============================] - 2832s 14s/step - loss: 0.4724 - accuracy: 0.8098 - auc: 0.8817 - val_loss: 0.4904 - val_accuracy: 0.8012 - val_auc: 0.8764 - lr: 2.5000e-05
# Epoch 35/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.8151 - auc: 0.8848
# Epoch 35: val_loss improved from 0.48440 to 0.46825, saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model_oversampled.h5
#
# Epoch 35: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_35_valacc_0.81.weights.h5
# 209/209 [==============================] - 2660s 13s/step - loss: 0.4675 - accuracy: 0.8151 - auc: 0.8848 - val_loss: 0.4682 - val_accuracy: 0.8090 - val_auc: 0.8839 - lr: 1.2500e-05
# Epoch 36/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4704 - accuracy: 0.8112 - auc: 0.8826
# Epoch 36: val_loss did not improve from 0.46825
#
# Epoch 36: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_36_valacc_0.78.weights.h5
# 209/209 [==============================] - 1831s 9s/step - loss: 0.4704 - accuracy: 0.8112 - auc: 0.8826 - val_loss: 0.5059 - val_accuracy: 0.7832 - val_auc: 0.8643 - lr: 1.2500e-05
# Epoch 37/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.8122 - auc: 0.8870
# Epoch 37: val_loss did not improve from 0.46825
#
# Epoch 37: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_37_valacc_0.79.weights.h5
# 209/209 [==============================] - 1494s 7s/step - loss: 0.4638 - accuracy: 0.8122 - auc: 0.8870 - val_loss: 0.4960 - val_accuracy: 0.7874 - val_auc: 0.8676 - lr: 1.2500e-05
# Epoch 38/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4674 - accuracy: 0.8154 - auc: 0.8845
# Epoch 38: val_loss did not improve from 0.46825
#
# Epoch 38: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_38_valacc_0.80.weights.h5
# 209/209 [==============================] - 2757s 13s/step - loss: 0.4674 - accuracy: 0.8154 - auc: 0.8845 - val_loss: 0.4848 - val_accuracy: 0.7952 - val_auc: 0.8749 - lr: 1.2500e-05
# Epoch 39/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4648 - accuracy: 0.8133 - auc: 0.8861
# Epoch 39: val_loss did not improve from 0.46825
#
# Epoch 39: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_39_valacc_0.80.weights.h5
# 209/209 [==============================] - 2413s 12s/step - loss: 0.4648 - accuracy: 0.8133 - auc: 0.8861 - val_loss: 0.4901 - val_accuracy: 0.7964 - val_auc: 0.8699 - lr: 6.2500e-06
# Epoch 40/100
# 209/209 [==============================] - ETA: 0s - loss: 0.4671 - accuracy: 0.8140 - auc: 0.8851
# Epoch 40: val_loss did not improve from 0.46825
#
# Epoch 40: saving model to C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\oversample_epochbyepoch\epoch_40_valacc_0.80.weights.h5
# 209/209 [==============================] - 1417s 7s/step - loss: 0.4671 - accuracy: 0.8140 - auc: 0.8851 - val_loss: 0.4780 - val_accuracy: 0.8042 - val_auc: 0.8754 - lr: 6.2500e-06

# %%
model.save(r'C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Models\finished_crop_resnet_oversampled.h5')

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title('Accuracy over epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# Plot Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss over epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# Plot AUC if included in metrics
if 'auc' in history.history:
    plt.plot(history.history['auc'], label='Train AUC')
    plt.plot(history.history['val_auc'], label='Val AUC')
    plt.legend()
    plt.title('AUC over epochs')
    plt.xlabel('Epochs')
    plt.ylabel('AUC')
    plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc, confusion_matrix
from tensorflow.keras.models import load_model

# Load best saved weights
#model.load_weights(r'C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\weights\best_model.weights.h5')

def evaluate_model(model, generator, steps, model_name="Model"):
    if hasattr(generator, 'on_epoch_end'):
        generator.on_epoch_end()

    y_true = []
    y_pred_prob = []
    
    for i in range(steps):
        if hasattr(generator, '__getitem__'):
            batch_x, batch_y = generator.__getitem__(i)
        else:
            batch_x, batch_y = next(generator.generate())
            
        batch_pred = model.predict(batch_x, verbose=0)
        
        y_true.extend(batch_y)
        y_pred_prob.extend(batch_pred)

    y_true = np.array(y_true).flatten()
    y_pred_prob = np.array(y_pred_prob).flatten()
    
    y_pred = (y_pred_prob > 0.5).astype(int)

    # --- Classification Report ---
    print(f"\n--- {model_name} Classification Report ---")
    print(classification_report(y_true, y_pred, target_names=['Benign', 'Malignant']))

    # --- Confusion Matrix ---
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(f'{model_name} Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(2)
    plt.xticks(tick_marks, ['Benign', 'Malignant'], rotation=45)
    plt.yticks(tick_marks, ['Benign', 'Malignant'])

    thresh = cm.max() / 2.
    for i in range(2):
        for j in range(2):
            plt.text(j, i, format(cm[i, j], 'd'),
                     ha="center", va="center",
                     color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.tight_layout()
    
    cm_path = fr'C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\result3_oversampled\oversampled_finished_confusion_matrix.png'
    plt.savefig(cm_path)
    print(f"Confusion matrix saved to: {cm_path}")
    plt.close()

    # --- ROC Curve ---
    fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6, 5))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{model_name} ROC Curve')
    plt.legend(loc="lower right")
    
    roc_path = fr'C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\result3_oversampled\oversampled_finished_roc_curve.png'
    plt.savefig(roc_path)
    print(f"ROC curve saved to: {roc_path}")
    plt.close()

    return {
        'accuracy': (y_pred == y_true).mean(),
        'auc': roc_auc,
        'y_true': y_true,
        'y_pred': y_pred,
        'y_pred_prob': y_pred_prob,
        'confusion_matrix': cm
    }

results = evaluate_model(model, test_gen, len(test_gen), model_name="Oversampled_ResNet50")

print(f"\n Final Accuracy: {results['accuracy']:.4f}, AUC: {results['auc']:.4f}")

print("\nConfusion Matrix:")
print(results['confusion_matrix'])
# Out:
# --- Oversampled_ResNet50 Classification Report ---
#               precision    recall  f1-score   support
#
#       Benign       0.84      0.71      0.77       835
#    Malignant       0.75      0.87      0.80       835
#
#     accuracy                           0.79      1670
#    macro avg       0.80      0.79      0.79      1670
# weighted avg       0.80      0.79      0.79      1670
#
# Confusion matrix saved to: C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\result3_oversampled\oversampled_finished_confusion_matrix.png
# ROC curve saved to: C:\Users\yaruu\OneDrive\Documents\DIS Copenhagen 2025\Courses\ANN & DL\Final Project\Datasets\CMMD_Clean\result3_oversampled\oversampled_finished_roc_curve.png
#
#  Final Accuracy: 0.7892, AUC: 0.8721
#
# Confusion Matrix:
# [[594 241]
#  [111 724]]
